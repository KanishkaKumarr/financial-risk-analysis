# %%
import pandas as pd

# %%
df = pd.read_csv("../data/cleaned_transactions.csv")
df.head()
# Out:
#    TransactionID CustomerID AccountID AccountType TransactionType  \
# 0             33   CUST6549  ACC12334      credit      withdrawal
# 1            177   CUST2942  ACC52650      credit      withdrawal
# 2            178   CUST6776  ACC45101     current         deposit
# 3            173   CUST2539  ACC88252     current      withdrawal
# 4             67   CUST2626  ACC21878     savings      withdrawal
#
#            Product    Firm   Region    Manager TransactionDate  \
# 0  Savings Account  Firm C  Central  Manager 1      2023-10-21
# 1        Home Loan  Firm A     East  Manager 3      2023-06-20
# 2    Personal Loan  Firm C    South  Manager 3      2023-01-02
# 3      Mutual Fund  Firm A  Central  Manager 2      2023-07-25
# 4        Home Loan  Firm C  Central  Manager 4      2023-07-25
#
#    TransactionAmount  AccountBalance  RiskScore  CreditRating  TenureMonths  \
# 0        87480.05448     74008.43310   0.729101           319           200
# ...

# %%
df['TransactionDate'] = pd.to_datetime(
    df['TransactionDate'],
    errors='coerce'
)

# %%
df.to_csv("../data/cleaned_transactions.csv", index=False)
print("✅ cleaned_transactions.csv verified and saved")
# Out:
# ✅ cleaned_transactions.csv verified and saved

# %% [markdown]
# ## Insights
# - The cleaned transaction dataset was loaded and verified for consistency.
# - Date formats were standardized to support time-based analysis.
# - Using a validated dataset ensures reliable downstream analysis.
